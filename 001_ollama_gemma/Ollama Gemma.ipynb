# %%
from langchain_community.llms import Ollama

# model
llm = Ollama(model="gemma:latest")

# chain 실행
response = llm.invoke("지구의 자전 주기는?")

# %%
response
# Out:
# '지구의 자전 주기는 약 24시간입니다. 지구는 자전에 의해 매일 한 바늘을 따라 돈니다. 이는 지구가 행성의 공전을 일으키는 원인이기도 합니다.'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("You are an expert in astronomy. Answer the question. <Question>: {input}")

# chain 연결 (LCEL)
chain = prompt | llm

# chain 호출
response = chain.invoke({"input": "지구의 자전 주기는?"})

# %%
response
# Out:
# '지구의 자전 주기는 24 시간입니다. 지구가 자전하는 속도는 약 1600 km/s입니다. 지구가 자전하는 주기는 지구가 자전하는 속도와 관련이 있습니다.'

# %%
from langchain_core.output_parsers import StrOutputParser

# prompt + model + output parser
prompt = ChatPromptTemplate.from_template("You are an expert in astronomy. Answer the question. <Question>: {input}")
output_parser = StrOutputParser()

# LCEL chaining
chain = prompt | llm | output_parser

# chain 호출
response = chain.invoke({"input": "지구의 자전 주기는?"})

# %%
response
# Out:
# '지구의 자전 주기는 약 24 시간입니다. 지구는 자전축에 대비하여 매일 한 번씩 회전합니다. 이 회전은 지구가 일주일동안 궤적을 따라 돈다는 것을 의미합니다.'
