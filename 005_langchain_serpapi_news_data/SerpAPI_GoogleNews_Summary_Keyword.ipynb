# %% [markdown]
# # 환경 설정

# %%
# !pip install -q langchain langchain-openai google-search-results

# %%
import os

os.environ['OPENAI_API_KEY'] = 'OPENAI_API_KEY'
os.environ['SERPAPI_API_KEY'] = 'SERPAPI_API_KEY'

# %% [markdown]
# # News 데이터 수집 - SerpAPI 활용
# - 인증키 발급 필요 (월 100회 무료)
# - https://serpapi.com/

# %%
from langchain_community.utilities import SerpAPIWrapper

params = {
    "engine": "google_news",
    "gl": "KR",
    "hl": "ko",
}
search = SerpAPIWrapper(params=params)

search.run("이차전지 산업")
# Out:
# [{'position': 1,
#   'title': '이차전지 산업 성과와 향후 과제는',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240311000263',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNUtaRTVuVm5NeE5rMWFWelJoVFJDZUFSaV9BaWdCTWdtTlVJUkdUcU10S1FJ',
#   'date': '03/11/2024, 05:26 AM, +0000 UTC'},
#  {'position': 2,
#   'title': "윤신애 군산시의원, '군산새만금 이차전지산업 발전위원회 설치 및 운영조례안' 상임위 원안가결",
#   'source': {'name': '아시아뉴스전북',
#    'icon': 'https://lh3.googleusercontent.com/nZlhiltG9uR2vUQm8WBs6MzhLXR-3jHN4O9iCozhAKD2hB-7jwHR_kGYPmgm8EH8Hw7M_5-WiTU'},
#   'link': 'http://www.mjeonbuk.com/news/articleView.html?idxno=71297',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWZiVmsyWVMxRVkwZEpORGxZVFJDVEFoaTNBU2dCTWdZcFZKcU9vUWc',
#   'date': '03/12/2024, 06:56 AM, +0000 UTC'},
#  {'position': 3,
#   'title': '[이차전지특구-충북②] 충북도 김명규 경제부지사, “국내 1위 넘어 글로벌 배터리 산업의 핵심 거점으로… 전 밸류체인 역량 ...',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52586',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDBaME4yTkdKMGF6YzVSVmxXVFJDM0FSaVRBaWdCTWdZcE5wck5HUW8',
#   'date': '03/07/2024, 01:00 AM, +0000 UTC'},
#  {'position': 4,
#   'title': '[프리뷰 2024 ②] 주춤하는 전기차 시장, 올해 이차전지 산업은?',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=85474',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVhPVnBCYWtoWVJsQXdiRkV4VFJDb0FSaXNBaWdCTWdhTmxKQklOZ1k',
#   'date': '01/03/2024, 08:00 AM, +0000 UTC'},
#  {'position': 5,
#   'title': '[특징주] 필에너지, 정부 이차전지 투자 발표에 주가 급등',
#   'source': {'name': '에너지경제',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.ekn.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.ekn.kr/web/view.php?key=20240312027553251',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iKkNnNDRTVWhyV0dkV1R6bFJVR3hyVFJCN0dMZ0NLQUV5QmcyU2tpazVCdw',
#   'date': '03/12/2024, 01:11 AM, +0000 UTC'},
#  {'position': 6,
#   'title': '경북도, 이차전지 산업생태계와 산업단지 홍보 등 기업유치 활동 실시',
#   'source': {'name': 'Save Internet 뉴데일리',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://tk.newdaily.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://tk.newdaily.co.kr/site/data/html/2024/03/06/2024030600420.html',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXdSRTFMT1ZSc2VYQkpaM2xRVFJDNEFSaVNBaWdCTWdZQmNJanZ5QU0',
#   'date': '03/06/2024, 02:19 PM, +0000 UTC'},
#  {'position': 7,
#   'title': '전고체전지에 이차전지 다시 주목 받나 했더니…대장주들은 뒷걸음',
#   'source': {'name': '네이트 뉴스',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://news.nate.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://news.nate.com/view/20240311n41221?mid=n1101',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWliM0pGVFdSdU0yVk9VVXR0VFJDU0FSalpBaWdCTWdZSkFaQ0tEUTA',
#   'date': '03/11/2024, 09:01 PM, +0000 UTC'},
#  {'position': 8,
#   'title': '이차전지 시장, 중국 입김 더욱 거세진다',
#   'source': {'name': '산업일보',
#    'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://kidd.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://kidd.co.kr/news/235904',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUdlVUZvYW14ZlYzTTBXR0pmVFJDM0FSaVRBaWdCTWdZQllvaHFyUVk',
#   'date': '03/04/2024, 11:35 PM, +0000 UTC'},
#  {'position': 9,
#   'title': '경북TP, 산업 분야별 전문성 강화 위한 조직 개편',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240312000127',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNWFRM0Y1ZUd4dFdHdE1hMlYzVFJDbkFSaXVBaWdCTWdNZHdRQQ',
#   'date': '03/12/2024, 02:16 AM, +0000 UTC'},
#  {'position': 10,
#   'title': '[이차전지특구-충북③] 충북TP 권성욱 정책기획단장, “소부장부터 대기업까지… 이차전지 산업 경쟁력 확보 위해 가교역할 ...',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52588',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXlRbTlmVEhCT1dUSXlUR0ZFVFJDWUFSakxBaWdCTWdZNU5KaHdIUWs',
#   'date': '03/07/2024, 11:30 PM, +0000 UTC'},
#  {'position': 11,
#   'title': "[인터배터리 2024] 세한, 이차전지 공정용 정밀 에어샤프트로 '눈길'",
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/news/article.html?no=87615',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNU9jbXhITWpsVk1tOVpiMFl6VFJDakFSaTBBaWdCTWdrQk1JcnRKR2VZaHdJ',
#   'date': '03/11/2024, 05:46 AM, +0000 UTC'},
#  {'position': 12,
#   'title': '한국전지학회 김동욱 회장, “이차전지 발전 위한 정보·기술·인력 협력의 장 만들 것”',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52591',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXZVVGQxU0VZM1ltbEZObGxvVFJDM0FSaVRBaWdCTWdZMWRJNXdyUWM',
#   'date': '03/07/2024, 05:00 AM, +0000 UTC'},
#  {'position': 13,
#   'title': '인하대, 제1회 지·산·학 이차전지 성과포럼 성료',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240312000147',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUxPRU5JTVhKT05rbDJhemhzVFJDM0FSaVRBaWdCTWdhQklJcXpwQWM',
#   'date': '03/12/2024, 02:37 AM, +0000 UTC'},
#  {'position': 14,
#   'title': "이차전지 전시회 인터배터리 2024 개막 '역대 최대규모'",
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/news/article.html?no=87462',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUdZblZpVmtOTmRXczBVVjlTVFJDM0FSaVRBaWdCTWdZQjhJYkJ6Z00',
#   'date': '03/06/2024, 08:57 AM, +0000 UTC'},
#  {'position': 15,
#   'title': '[이차전지특구-충북①] K-배터리의 중심 충북… 초격차 기술로 글로벌 No.1 도전',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52575',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNWtNRGN5VTNaMk0xcDVaMk15VFJDcUFSaXBBaWdCTWdNQm9BUQ',
#   'date': '03/06/2024, 05:00 AM, +0000 UTC'},
#  {'position': 16,
#   'title': '전북특별자치도, 이차전지·방위·바이오 등 3대 신산업 집중 육성 박차',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240311000051',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVNaSFpIZHpSM09VdDVZMnhCVFJDM0FSaVRBaWdCTWdhQmdJYXVxUVk',
#   'date': '03/11/2024, 12:56 AM, +0000 UTC'},
#  {'position': 17,
#   'title': '[B트렌드] K-배터리 신년사로 살펴본 2024년 이차전지 산업 미리보기',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52024',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXZPRFphV2tKV1Ewc3hWVVoyVFJDM0FSaVRBaWdCTWdhbGhKS3RNUWM',
#   'date': '01/07/2024, 08:00 AM, +0000 UTC'},
#  {'position': 18,
#   'title': '충청권 이차전지 산업 성과 공유 워크숍 개최… 배터리 정책·동향 공유',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=51662',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNHlibDlwVjFOcmEyNHhWMUJXVFJDeEFSaWNBaWdCTWdZQm9ZZ0dVUVU',
#   'date': '11/28/2023, 08:00 AM, +0000 UTC'},
#  {'position': 19,
#   'title': '[이차전지특구-포항③] 이영주 부국장, “이차전지 산업은 세계 경제의 핵심… 글로벌 시장 선점 전략 마련해야”',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52369',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXZiVVIxYmtrNGNHb3liRTUyVFJDM0FSaVRBaWdCTWdhaE5vSXJuZ2s',
#   'date': '02/13/2024, 08:00 AM, +0000 UTC'},
#  {'position': 20,
#   'title': "충북도, 이차전지 산업 집적화 강화… '배터리 제조·검증 지원센터' 문 열어",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52311',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUdlbWx4UWpCaE56bEZTVTk0VFJDckFSaW1BaWdCTWdZQm9JNEpRUVk',
#   'date': '02/03/2024, 08:00 AM, +0000 UTC'},
#  {'position': 21,
#   'title': '충북, 세계 배터리산업 이차전지산업 육성한다',
#   'source': {'name': '천지일보',
#    'icon': 'https://lh3.googleusercontent.com/HV2XXAUXe9ndEH79C5HkdvV_ZcOVcFqCWDAr0Y834vCrzFM6gYZS5TgjmcT0husM0Nyq22D9'},
#   'link': 'https://www.newscj.com/news/articleView.html?idxno=3113385',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVBjblIzWW14bE1VaFVWVUpXVFJDM0FSaVRBaWdCTWdhQkJaYk1xUWM',
#   'date': '02/28/2024, 03:28 PM, +0000 UTC'},
#  {'position': 22,
#   'title': '2차전지 산업 이끄는 전기차 배터리, 시장 변수는?',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=79350',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNU1RVXhyVW10cWQyMUxTVnBHVFJDM0FSaVRBaWdCTWdzUllvWktOV1JVYW5yc1BB',
#   'date': '06/29/2023, 07:00 AM, +0000 UTC'},
#  {'position': 23,
#   'title': '“에코프로, 올해 국내 이차전지 사업에 1조2천억 투자한다”',
#   'source': {'name': '에너지데일리',
#    'icon': 'https://lh3.googleusercontent.com/3ed_VVui8mkGhVfxoH44YNuhUXFsP3Lgbl1jDAQqihnbwgbaA4nEUGBqkcGQ2NrBBBJBGZaGOQ'},
#   'link': 'https://www.energydaily.co.kr/news/articleView.html?idxno=144689',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWhURTgyVDNWU2VrUk1kemRTVFJDb0FSaXNBaWdCTWdhQmdJUXFOUVU',
#   'date': '03/11/2024, 12:39 AM, +0000 UTC'},
#  {'position': 24,
#   'title': '포항시, 전지보국 실현 위한 전문가 의견 수렴',
#   'source': {'name': '데일리대구경북뉴스',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=http://www.dailydgnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.dailydgnews.com/news/article.html?no=179197',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUJlSEZLTUY5ZlEwcGpOVko0VFJDcUFSaW9BaWdCTWdhTlFZN0h0QVU',
#   'date': '03/06/2024, 08:21 AM, +0000 UTC'},
#  {'position': 25,
#   'title': '테슬라에 죽쓴 이차전지...K배터리가 살릴까',
#   'source': {'name': '이코노미스트',
#    'icon': 'https://lh3.googleusercontent.com/fauvezMo_XC6GfCBZ9ZICC7GjWaB5_kOMn7SvEm54g4IeLeKbQMzAINg0dWl6lvCzG4VqObpNw'},
#   'link': 'https://economist.co.kr/article/view/ecn202403080027',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNURVSEZ5ZDFOSGNFZHdRMXBCVFJDcEFSaXFBaWdCTWdrQlVZN2hwR1ZqTlFF',
#   'date': '03/09/2024, 04:49 AM, +0000 UTC'},
#  {'position': 26,
#   'title': '이강덕 시장, 2024 인터배터리 현장 방문…이차전지 네트워크 강화',
#   'source': {'name': '미디어경북',
#    'icon': 'https://lh3.googleusercontent.com/E9g0vpVvxzZz0VYv4oYtW_fo5hdcsrVq8hjgvNJ9kGHInNxUp5nkKvX-a0O7xJy2gwZ0Gv_9_g'},
#   'link': 'http://www.mediagb.kr/news/view.php?idx=34531',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNUdTa1JHV1hCSU4xTTBiMHRuVFJDM0FSaVVBaWdCTWdrTmtKQm50bWM5c0FF',
#   'date': '03/08/2024, 02:01 AM, +0000 UTC'},
#  {'position': 27,
#   'title': '[신년기획] 전문가들이 본 이차전지 산업 전망은?',
#   'source': {'name': '이코리아',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.ekoreanews.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.ekoreanews.co.kr/news/articleView.html?idxno=71246',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iKkNnNVZMVlpTYXpjelFVaFpkV3BRVFJCN0dKa0RLQUV5Qm9WZ2pLaXdCdw',
#   'date': '01/15/2024, 08:00 AM, +0000 UTC'},
#  {'position': 28,
#   'title': '에코프로, 올해 1.2조원 쏟는다…이차전지 복합 투자',
#   'source': {'name': '한국경제',
#    'icon': 'https://lh3.googleusercontent.com/xDmd1nksxaeS7dRPFdQgYUkSl-X_6-fUooei4P_IS4a2ZqrlbiADcaFSzfpSt4s2A3wUx7A_mIQ'},
#   'link': 'https://www.hankyung.com/article/2024031093805',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVhja2cwVXpSWFltSTJOVXA2VFJDb0FSaXNBaWdCTWdhQmNJUXB0UVU',
#   'date': '03/10/2024, 02:25 AM, +0000 UTC'},
#  {'position': 29,
#   'title': '충북도 이차전지 육성 총력…세계 배터리산업 중심지 발돋움',
#   'source': {'name': '충북일보',
#    'icon': 'https://lh3.googleusercontent.com/yUwH0278wYbMq_jtk67wzQV0kg99hShH8PZqnGwkXM8ui7rlf4Uke6gbTP1bcB54-iJ9bwym6Q'},
#   'link': 'https://www.inews365.com/news/article.html?no=803482',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNUhWazVWTmpkMFEwcDNhbEU0VFJDM0FSaVRBaWdCTWdNQmtBbw',
#   'date': '02/28/2024, 08:15 AM, +0000 UTC'},
#  {'position': 30,
#   'title': '충북도 이차전자산업 육성 박차...세계 배터리산업 중심 도약',
#   'source': {'name': '뉴스핌',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.newspim.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.newspim.com/news/view/20240228000256',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDVkV28zTFdsQk1HcEdMV2RsVFJDbkFSaXRBaWdCTWdhQk1ZN1RJQVk',
#   'date': '02/28/2024, 12:37 AM, +0000 UTC'},
#  {'position': 31,
#   'title': '이차전지산업 대대적 지원…5년간 정책금융 38조원, 규제완화 등',
#   'source': {'name': '인사이드비나',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=http://www.insidevina.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.insidevina.com/news/articleView.html?idxno=26071',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWplbFZSVGpkb1MySnVjVEJOVFJDS0FSanNBaWdCTWdZMUlvb1JJUVU',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 32,
#   'title': "대전시, '이차전지산업'을 새로운 미래 먹거리로 육성한다",
#   'source': {'name': '이로운넷',
#    'icon': 'https://lh3.googleusercontent.com/OcV9izZMrni0t-cwj5EzcvKhXkIkhIBOevqMfnc00HR61bl-OpbDxM0IpeJ5dsRgaQtoZmmAoQ'},
#   'link': 'https://www.eroun.net/news/articleView.html?idxno=38421',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXNVa3RvZGxFd2RqTnVOMjFmVFJDM0FSaVRBaWdCTWdrQmdKQTV1T2JRemdF',
#   'date': '11/02/2023, 07:00 AM, +0000 UTC'},
#  {'position': 33,
#   'title': '포항시-중국 간저우시, 이차전지산업 교류 협력',
#   'source': {'name': '경상매일신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=http://www.ksmnews.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.ksmnews.co.kr/news/view.php?idx=469707',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iI0NnNWFhVlpmT1dGU1pHSnZWRk5EVFJDM0FSaVRBaWdCTWdB',
#   'date': '02/25/2024, 11:19 AM, +0000 UTC'},
#  {'position': 34,
#   'title': '비투에스, 인터배터리서 이차전지 품질검사 고도화 장비 전시',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/news/article.html?no=87545',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXhhbU5sVFhkaWJGQnRTMDVuVFJDQkFSaUZBeWdCTWdtSlk1TG1NdWh6Q2dJ',
#   'date': '03/08/2024, 07:04 AM, +0000 UTC'},
#  {'position': 35,
#   'title': "포스코그룹, '인터배터리 2024'에서 이차전지소재사업 선보인다",
#   'source': {'name': 'POSCO Newsroom',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://newsroom.posco.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://newsroom.posco.com/kr/%ED%8F%AC%EC%8A%A4%EC%BD%94%EA%B7%B8%EB%A3%B9-%EC%9D%B8%ED%84%B0%EB%B0%B0%ED%84%B0%EB%A6%AC-2024%EC%97%90%EC%84%9C-%EC%9D%B4%EC%B0%A8%EC%A0%84%EC%A7%80%EC%86%8C%EC%9E%AC%EC%82%AC/',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNVBVbVZ0Y1dGelZXUkRTa0pwVFJDSEFSajJBaWdCTWdrSllaQ2tQZVl0QndJ',
#   'date': '03/05/2024, 12:52 AM, +0000 UTC'},
#  {'position': 36,
#   'title': '"침체기 빠진 이차전지 산업, 내년도 어렵다"',
#   'source': {'name': '한국경제',
#    'icon': 'https://lh3.googleusercontent.com/xDmd1nksxaeS7dRPFdQgYUkSl-X_6-fUooei4P_IS4a2ZqrlbiADcaFSzfpSt4s2A3wUx7A_mIQ'},
#   'link': 'https://www.hankyung.com/article/2023110954556',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUVXbXRQUTFacWIybFZlbFJPVFJDckFSaW1BaWdCTWdhQk1ZNEhvZ2s',
#   'date': '11/10/2023, 08:00 AM, +0000 UTC'},
#  {'position': 37,
#   'title': '경북테크노파크, 이차전지산업 맞춤형 인재 양성 박차',
#   'source': {'name': '서울경제TV',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.sentv.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.sentv.co.kr/news/view/680025',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWlVeTFCWDJ4bFVGTnRWSGhQVFJDZUFSaS1BaWdCTWdhZE1vakxHUW8',
#   'date': '02/21/2024, 11:24 AM, +0000 UTC'},
#  {'position': 38,
#   'title': '"이차전지 산업을 5대 주력산업으로" < 사회일반 < 사회 < 뉴스 < 기사본문',
#   'source': {'name': '울산매일',
#    'icon': 'https://lh3.googleusercontent.com/deQpo_rH64LFypDh4L9QObTDkDJTIj5JkOlA6_ppNaW5hyBizGyUG1cprffj5_j_KGAh-MUw'},
#   'link': 'https://www.iusm.co.kr/news/articleView.html?idxno=1029541',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNTVPRU5hZURSaVYzTmxWbXRPVFJDRkFSajZBaWdCTWdNQlFBUQ',
#   'date': '12/07/2023, 08:00 AM, +0000 UTC'},
#  {'position': 39,
#   'title': "한국유미코아 배터리머티리얼즈, '인터배터리 2024' 참가",
#   'source': {'name': '뉴스1',
#    'icon': 'https://lh3.googleusercontent.com/WKdVyZCY_ivq2SMbAkrrfcDXEuKyXFVaWelXqqLPtzQfzUhIlAHuJBA75zL20uXRwGXkMrJ3'},
#   'link': 'https://www.news1.kr/articles/?5347363',
#   'date': '03/12/2024, 01:23 AM, +0000 UTC'},
#  {'position': 40,
#   'title': "경북도, '인터배터리 2024' 참가…이차전지 소재산업 중심 도시 적극 홍보",
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240306000063',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJkNnNXZPRk5FYzFkclJIbDVNa1JYVFJCNEdLUURLQUV5QTRGQkJn',
#   'date': '03/06/2024, 01:12 AM, +0000 UTC'},
#  {'position': 41,
#   'title': '새만금 이차전지 산업의 비상을 꿈꾸며',
#   'source': {'name': '전북일보',
#    'icon': 'https://lh3.googleusercontent.com/3b4nzoOUmmJS8hFJUfJQCgYVTpOcUsUshjmZpWjCXna4oqkJBxizj6OpcPgN2uH6b1KhDYB5xA'},
#   'link': 'https://www.jjan.kr/article/20240213580123',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDJaVk42U0hOdU1tTlFZbWt0VFJETEFSaVlBU2dCTWdZaFpaVExKUWc',
#   'date': '02/14/2024, 08:00 AM, +0000 UTC'},
#  {'position': 42,
#   'title': '인하대 “이차전지산업 전문 인재 양성기관으로 중추적 역할 할 것”',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20240226000137',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNTNVR0pUYmkxeWQxaFJWMnR1VFJDMEFSaVlBaWdCTWdzQmNJcmt4Q1ZFTnZsY2Vn',
#   'date': '02/26/2024, 01:49 AM, +0000 UTC'},
#  {'position': 43,
#   'title': "전남도, '지역특화 레전드 50+' 참여기업 모집… 이차전지 산업 본격 육성",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52133',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDRUWGROU1VFMVJqZHJNR1ExVFJDM0FSaVRBaWdCTWdZaFJKSnNJUWs',
#   'date': '01/16/2024, 08:00 AM, +0000 UTC'},
#  {'position': 44,
#   'title': '인하대, 제1회 지·산·학 이차전지 성과포럼 개최',
#   'source': {'name': '뉴스티앤티',
#    'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=http://www.newstnt.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.newstnt.com/news/articleView.html?idxno=351661',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTRVRUl4ZWtSak5EQkVWbGhOVFJDM0FSaVRBaWdCTWdhRlFaSW1JUWc',
#   'date': '03/11/2024, 04:54 AM, +0000 UTC'},
#  {'position': 45,
#   'title': "[2023 국감] 이차전지 역수입 가속화 현상에 '단기 호재' 우려… 수급계획 세워야",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=51172',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNTNiRGhXVFVoTGQwRlVMV3cwVFJDM0FSaVRBaWdCTWdzQkFJcGxKU1VyNWxxbVJR',
#   'date': '10/10/2023, 07:00 AM, +0000 UTC'},
#  {'position': 46,
#   'title': '이차전지 산업 생태계 고도화 … 미래 핵심 먹거리 육성 [지방기획]',
#   'source': {'name': '세계일보',
#    'icon': 'https://lh3.googleusercontent.com/9zw_u8l5BuH8JToqUb5swHPKFxZZ4TF6qr66s_OmPKqbDgOE7njcpQqesEHmugUjVOfukyP_2Yc'},
#   'link': 'https://m.segye.com/view/20231108519202',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNHlMVll5VjJGTldHMXNkVlk0VFJDdUFSaWlBaWdCTWdNQllBNA',
#   'date': '11/08/2023, 08:00 AM, +0000 UTC'},
#  {'position': 47,
#   'title': '이차전지 공정 내 작업 안전 환경 구축 및 개선 방안은?',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=79605',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVhZazVaV1doUVFWWjNiRVZIVFJDcUFSaXBBaWdCTWdZQmtJcDF3QVU',
#   'date': '07/05/2023, 07:00 AM, +0000 UTC'},
#  {'position': 48,
#   'title': '전북도, 새만금 사용후 이차전지 산업 생태계 조성 전략회의 개최',
#   'source': {'name': '전자신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etnews.com/20231228000047',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXpjbXRDWVRJdFRUY3lTWGxRVFJDM0FSaVRBaWdCTWdrZFJJTE5vZUthMHdB',
#   'date': '12/28/2023, 08:00 AM, +0000 UTC'},
#  {'position': 49,
#   'title': '충북, 우리나라 이차전지 산업을 이끌어간다',
#   'source': {'name': '이로운넷',
#    'icon': 'https://lh3.googleusercontent.com/OcV9izZMrni0t-cwj5EzcvKhXkIkhIBOevqMfnc00HR61bl-OpbDxM0IpeJ5dsRgaQtoZmmAoQ'},
#   'link': 'https://www.eroun.net/news/articleView.html?idxno=40132',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUVSa2hDYkU1WlFVRlVTV0k1VFJDM0FSaVRBaWdCTWdhVlVwQUlNUWM',
#   'date': '01/30/2024, 08:00 AM, +0000 UTC'},
#  {'position': 50,
#   'title': "'2023 울산 K-배터리 쇼' 성료… 이차전지 산업 현재와 미래 조명",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=51779',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDFSWEk1YzI1MVowbDVVa0ZtVFJDM0FSaVRBaWdCTWdZQmdJZ2lOQVU',
#   'date': '12/08/2023, 08:00 AM, +0000 UTC'},
#  {'position': 51,
#   'title': '[마켓톺] "간만에 한번 웃었다" 이차전지 먹구름 언제쯤',
#   'source': {'name': '연합뉴스',
#    'icon': 'https://lh3.googleusercontent.com/fM82M1aLWdXllyEVRyWmXgo-uQooEQJ86PY07ZUMJYxZnUkmfYKlN7VhGsQF80dwYqgu-jjttg'},
#   'link': 'https://www.yna.co.kr/view/AKR20240307131800008',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXlRV3BFTjFjd1pGaE9UbVpMVFJEQ0FSaURBaWdCTWdZQk1JcUxMUVU',
#   'date': '03/07/2024, 07:44 AM, +0000 UTC'},
#  {'position': 52,
#   'title': '대전시, 20억 원 투입 이차전지산업 육성 지원 사업 본격 추진',
#   'source': {'name': '충남일보',
#    'icon': 'https://lh3.googleusercontent.com/KR3Pg6ov1jOljnelJqfJDwZNhYY8ae7jagZOavKLY6cNDskIDwcAaT8bPgZJ31XK3ToA5JPPPw'},
#   'link': 'https://www.chungnamilbo.co.kr/news/articleView.html?idxno=754560',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTJiUzF6YmtWamJsOWpZWEJGVFJDX0FSaUlBaWdCTWdhSkVvU3RuUWM',
#   'date': '01/29/2024, 08:00 AM, +0000 UTC'},
#  {'position': 53,
#   'title': "배터리의 무한 영역확장...도심항공·방위산업 등 미래 산업용 배터리시장 '쑥쑥'",
#   'source': {'name': '디일렉',
#    'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.thelec.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.thelec.kr/news/articleView.html?idxno=26080',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNW1ZbEpJVlRSVGRsaGlZbWxmVFJDVEFoaTNBU2dCTWdZQlFJeEluZ2s',
#   'date': '02/22/2024, 08:00 AM, +0000 UTC'},
#  {'position': 54,
#   'title': '대전TP, 이차전지산업 기업지원에 10억 투입',
#   'source': {'name': '충남일보',
#    'icon': 'https://lh3.googleusercontent.com/KR3Pg6ov1jOljnelJqfJDwZNhYY8ae7jagZOavKLY6cNDskIDwcAaT8bPgZJ31XK3ToA5JPPPw'},
#   'link': 'https://www.chungnamilbo.co.kr/news/articleView.html?idxno=755364',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTJZemxJZVRkRU9Ia3RSMEZIVFJDeUFSaWJBaWdCTWdhZEpKVHNGUWM',
#   'date': '02/02/2024, 08:00 AM, +0000 UTC'},
#  {'position': 55,
#   'title': '2차전지, 내년 상반기까지는 \'춥다\'..."성장성 둔화 불가피"',
#   'source': {'name': '오피니언뉴스',
#    'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.opinionnews.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.opinionnews.co.kr/news/articleView.html?idxno=90572',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUdVbFJqT1ZOeE9EbEZhMWRHVFJDM0FSaVRBaWdCTWdhQkVJZ3NwUVk',
#   'date': '11/21/2023, 08:00 AM, +0000 UTC'},
#  {'position': 56,
#   'title': "이차전지 인프라 한눈에…경북도, '인터배터리 2024'서 홍보 활동 펼쳐",
#   'source': {'name': '경북일보',
#    'icon': 'https://lh3.googleusercontent.com/ALgghnDse3BDjRin-bYB51QKgHe_Cq6_TwDQiSbjXaBTiUTlIPOXmZUnfzBMZCYKEJH8-96ACQ'},
#   'link': 'http://www.kyongbuk.co.kr/news/articleView.html?idxno=4002889',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNU9RWFJYWTJ4RFpGUlpVaTFaVFJDNEFSaVJBaWdCTWdZQmNJanZ5QU0',
#   'date': '03/06/2024, 11:07 AM, +0000 UTC'},
#  {'position': 57,
#   'title': '인하대, 제1회 지·산·학 이차전지 성과 포럼 열어',
#   'source': {'name': '뉴스1',
#    'icon': 'https://lh3.googleusercontent.com/WKdVyZCY_ivq2SMbAkrrfcDXEuKyXFVaWelXqqLPtzQfzUhIlAHuJBA75zL20uXRwGXkMrJ3'},
#   'link': 'https://www.news1.kr/articles/?5346636',
#   'date': '03/11/2024, 06:58 AM, +0000 UTC'},
#  {'position': 58,
#   'title': '에코프로, 올해 국내 1.2兆 투자 집행…이차전지 복합 투자',
#   'source': {'name': '이투데이',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.etoday.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.etoday.co.kr/news/view/2338590',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDRlVWRyWlRNeldFbE9kMHhWVFJDb0FSaXNBaWdCTWdZQmdJWXJOUVU',
#   'date': '03/10/2024, 12:47 AM, +0000 UTC'},
#  {'position': 59,
#   'title': '"간만에 한번 웃었다" 이차전지 먹구름 언제쯤',
#   'source': {'name': '한국경제',
#    'icon': 'https://lh3.googleusercontent.com/xDmd1nksxaeS7dRPFdQgYUkSl-X_6-fUooei4P_IS4a2ZqrlbiADcaFSzfpSt4s2A3wUx7A_mIQ'},
#   'link': 'https://www.hankyung.com/article/202403074776Y',
#   'date': '03/07/2024, 07:45 AM, +0000 UTC'},
#  {'position': 60,
#   'title': '인하대, ‘이차전지산업 성과교류회·학교 간 투어’ 성료',
#   'source': {'name': '이뉴스투데이',
#    'icon': 'https://lh3.googleusercontent.com/HYW_HSNgNIK9ycRiz3nGq2yPg6gHt5oZnA8JswyTUf9dyX1-rsXntsEb6sjFRbA2Rs53ab3G'},
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2094277',
#   'date': '02/26/2024, 01:20 AM, +0000 UTC'},
#  {'position': 61,
#   'title': "이차전지 산업 현재·미래 한눈에…'울산 K-배터리 쇼' 개최",
#   'source': {'name': '연합뉴스',
#    'icon': 'https://lh3.googleusercontent.com/fM82M1aLWdXllyEVRyWmXgo-uQooEQJ86PY07ZUMJYxZnUkmfYKlN7VhGsQF80dwYqgu-jjttg',
#    'authors': ['김용태']},
#   'link': 'https://www.yna.co.kr/view/AKR20231207011800057',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDVhMUIxTldGUFMycFVWVE5IVFJDaUFSaTNBaWdCTWdhQlVaaUZwZ2s',
#   'date': '12/07/2023, 08:00 AM, +0000 UTC'},
#  {'position': 62,
#   'title': '국내 최대 배터리 전시회서 전북의 이차전지 산업·새만금 투자 인프라 전 세계 알린다',
#   'source': {'name': '전라일보',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=http://www.jeollailbo.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.jeollailbo.com/news/articleView.html?idxno=723138',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXBaSE51YkhoZk5sUXRkbDlZVFJDWkFSaklBaWdCTWdZQk40UUZWZ00',
#   'date': '03/05/2024, 07:27 AM, +0000 UTC'},
#  {'position': 63,
#   'title': "주춤하는 전기차 시장, 업계 동향에 '주목'",
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=85649',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDJXV2hGVVd4alJ5MUdjMFJzVFJDM0FSaVRBaWdCTWdZSldJaUdLZ1U',
#   'date': '01/08/2024, 08:00 AM, +0000 UTC'},
#  {'position': 64,
#   'title': '이차전지에 38조 정책금융…배터리 재사용 생태계 육성',
#   'source': {'name': '연합뉴스',
#    'icon': 'https://lh3.googleusercontent.com/fM82M1aLWdXllyEVRyWmXgo-uQooEQJ86PY07ZUMJYxZnUkmfYKlN7VhGsQF80dwYqgu-jjttg'},
#   'link': 'https://www.yna.co.kr/view/AKR20231212141600002',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDRUSFEzWDNacmRHUkpXVWczVFJDb0FSaXNBaWdCTWdZSlVJaUxwUVU',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 65,
#   'title': '전기차와 2차전지 산업, 어떤 방향으로 발전할까? - 금융이 알고 싶을 때',
#   'source': {'name': '토스피드',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://blog.toss.im&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://blog.toss.im/article/rechargeable-battery-industry',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNHdUVXh4YUV0MWFFNUJSMnMxVFJDNEFSaVJBaWdCTWdZaGxKS05OUWM',
#   'date': '12/18/2023, 08:00 AM, +0000 UTC'},
#  {'position': 66,
#   'title': '[국민의 기업] ‘K-배터리’종합 클러스터 구축해 국내 이차전지 산업 허브로 도약',
#   'source': {'name': '중앙일보',
#    'icon': 'https://lh3.googleusercontent.com/uRf9S6UGzKmznsVsplQbR9M9VkNwLD80dtwV9GkGeKJfIX2PY5B4oNaLRMQDiW3AbEibdwqX0g'},
#   'link': 'https://www.joongang.co.kr/article/25216478',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXRNRUp3TWpOSmQwcEVRMnh0VFJDZEFSakJBaWdCTWdZRkVvd3NuUVU',
#   'date': '12/20/2023, 08:00 AM, +0000 UTC'},
#  {'position': 67,
#   'title': '경기도의회, 이차전지산업 대비 나섰다',
#   'source': {'name': '경기일보',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.kyeonggi.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.kyeonggi.com/article/20240206580427',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVJXblUyWlVaYVRubE9UbXRtVFJDM0FSaVRBaWdCTWdZSmRaU3VLUWc',
#   'date': '02/06/2024, 08:00 AM, +0000 UTC'},
#  {'position': 68,
#   'title': '포항시, 배터리특성화대학원 포스텍 유치...이차전지 산업 이끌 핵심 고급 인재 양성',
#   'source': {'name': '아주경제',
#    'icon': 'https://lh3.googleusercontent.com/5719p8VRJJQO6PiAJ2o0g2GnSKxY49jsIwFqfq6c3duvqfD3OIShB5hYyz4A8WEDWXW3DV_M'},
#   'link': 'https://www.ajunews.com/view/20240222162446456',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVRiWEZtUVhwaFRGTTFkWEJsVFJDMkFSaVZBaWdCTWdZaEZLS0xFUXM',
#   'date': '02/22/2024, 08:00 AM, +0000 UTC'},
#  {'position': 69,
#   'title': "경북도,'이차전지 소재산업 중심' 홍보 유치",
#   'source': {'name': '메트로신문-중산층과 서민을 위한 알찬 정보',
#    'icon': 'https://lh3.googleusercontent.com/hx9pr0Axn4naIpr241uy4zxp6CMclVeoaMP7LvWBiEyDWiTP4dz8BtMvFAOUUZXJRQpaVtgbn88'},
#   'link': 'https://www.metroseoul.co.kr/article/20240306500382',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWlVMGM1VEZrNFMySjZNSGhQVFJDX0FSaUlBaWdCTWdZaE1JeU12UVU',
#   'date': '03/06/2024, 05:19 AM, +0000 UTC'},
#  {'position': 70,
#   'title': '경북 이차전지산업 클러스터 조성으로 첨단산업 미래먹거리 박차!',
#   'source': {'name': '데일리대구경북뉴스',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=http://www.dailydgnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.dailydgnews.com/mobile/article.html?no=166097',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNWFVRXhEVUVwVmEydzNRMnhYVFJDb0FSaXNBaWdCTWdNQlVBUQ',
#   'date': '09/24/2023, 07:00 AM, +0000 UTC'},
#  {'position': 71,
#   'title': '경북도， `인터배터리 전시회`서 이차전지 소재산업 알리고 기업 유치 `온힘`',
#   'source': {'name': '경북신문',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=http://www.kbsm.net&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'http://www.kbsm.net/news/view.php?idx=425020',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTZaMFF0YTFaMWRqTmtSek0zVFJDNEFSaVNBaWdCTWdZQmNJanZ5QU0',
#   'date': '03/06/2024, 05:47 AM, +0000 UTC'},
#  {'position': 72,
#   'title': '올해 배터리 산업과 전고체 배터리 전망은? 세미나 개최',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=85653',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNTViRVk0TjBoMmFteDFhR0YwVFJDb0FSaXNBaWdCTWdrQndJUmtSS09oN1FF',
#   'date': '01/09/2024, 08:00 AM, +0000 UTC'},
#  {'position': 73,
#   'title': '[초점] 이차전지가 에너지 미래다 - ①',
#   'source': {'name': '에너지데일리',
#    'icon': 'https://lh3.googleusercontent.com/3ed_VVui8mkGhVfxoH44YNuhUXFsP3Lgbl1jDAQqihnbwgbaA4nEUGBqkcGQ2NrBBBJBGZaGOQ'},
#   'link': 'http://www.energydaily.co.kr/news/articleView.html?idxno=143146',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTJVbmRhUjFGWmQyUlhVRmRXVFJDM0FSaVRBaWdCTWdhSllaYkdLQWs',
#   'date': '01/02/2024, 08:00 AM, +0000 UTC'},
#  {'position': 74,
#   'title': '인터배터리 "더 멀리·더 가볍게" K-배터리 신기술 한자리 [르포]',
#   'source': {'name': '뉴스저널리즘',
#    'icon': 'https://lh3.googleusercontent.com/5VvYX4HthKRpwb3eN2i_r0eTd6OL4CqJSvNc-mRgeM0gAxqSt5nnxdvYBUEyLKx2H2c8y8h3'},
#   'link': 'https://www.ngetnews.com/news/articleView.html?idxno=502855',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNVJYMnhEZG5oa2JuRjRWemhPVFJEQ0FSaURBaWdCTWdrRllKN0ZLcWtsU3dJ',
#   'date': '03/07/2024, 04:15 AM, +0000 UTC'},
#  {'position': 75,
#   'title': "경쟁 치열한 배터리 시장… 공급망 강화 및 제품 신뢰도 확보 '필수'",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=50833',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXlSVlZDUm5GWmQxUlZTa2hKVFJDWUFSakxBaWdCTWdrQmNJWkl3S1BJa1FF',
#   'date': '09/03/2023, 07:00 AM, +0000 UTC'},
#  {'position': 76,
#   'title': '배터리 시장은 예고된 블루오션…“K-배터리의 3대 과제는?”',
#   'source': {'name': '이코노믹리뷰',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.econovill.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.econovill.com/news/articleView.html?idxno=648250',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWtSVTV6WTBGalpVaHNPRUZqVFJEQ0FSaURBaWdCTWdZSkFJTXcyUU0',
#   'date': '03/08/2024, 08:58 AM, +0000 UTC'},
#  {'position': 77,
#   'title': '정부, 이차전지에 38兆 투자...공급망 내재화 등 배터리 산업 적극 육성',
#   'source': {'name': 'ZD넷 코리아',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://zdnet.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://zdnet.co.kr/view/?no=20231212163242',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNDRlRTlVTVVKQlYyazFlalpVVFJDM0FSaVRBaWdCTWdrQllJQkNUaVFtNXdF',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 78,
#   'title': "이차전지산업 현재·미래 한눈에…'울산 K-배터리쇼' 열려",
#   'source': {'name': '경상일보',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.ksilbo.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.ksilbo.co.kr/news/articleView.html?idxno=986810',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNU1lRlIwU1c1UWQzbEZiRFJxVFJDS0FSanVBaWdCTWdzQlVJSmxMQ1BZOHdpTnFn',
#   'date': '12/08/2023, 08:00 AM, +0000 UTC'},
#  {'position': 79,
#   'title': '충남TP, 충청권 이차전지 산업 성과 교류',
#   'source': {'name': '충청뉴스',
#    'icon': 'https://lh3.googleusercontent.com/2RLvPAIC7oi5BfUEDI4gnUg735YVonpE0j3Nre4YyGGee6CqFjavGIM02XiTnXwJC_LFyqTbzQ'},
#   'link': 'https://www.ccnnews.co.kr/news/articleView.html?idxno=316537',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNUVTR2RRVFVveGFrcFdhVFpqVFJDM0FSaVRBaWdCTWdNRmtBUQ',
#   'date': '11/28/2023, 08:00 AM, +0000 UTC'},
#  {'position': 80,
#   'title': '이차전지산업 미래는 어떨까…포항서 국제학술회의 열려',
#   'source': {'name': '연합뉴스',
#    'icon': 'https://lh3.googleusercontent.com/fM82M1aLWdXllyEVRyWmXgo-uQooEQJ86PY07ZUMJYxZnUkmfYKlN7VhGsQF80dwYqgu-jjttg'},
#   'link': 'https://www.yna.co.kr/view/AKR20231114146900053',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iNkNnNXNPVTlOYm5GQlFVcDVaV1JoVFJDMUFSaVhBaWdCTWc0QlFJYkdKS1RRVU5uWXVicUdEUQ',
#   'date': '11/14/2023, 08:00 AM, +0000 UTC'},
#  {'position': 81,
#   'title': "K-배터리 3사 포함, '차세대 이차전지' 산업 성장 위해 산·학·연·관 맞손",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=50344',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXVVREpxWkVaT1JUWlNlVVV3VFJDM0FSaVRBaWdCTWdrQklKYkRJZWtXQXdN',
#   'date': '07/13/2023, 07:00 AM, +0000 UTC'},
#  {'position': 82,
#   'title': "'2023 울산 케이-배터리 쇼' 12월 7일 개최… 글로벌 이차전지 현재와 미래 조망",
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=51707',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTBURk50ZDBOdGJqaFNWRXg0VFJDT0FSampBaWdCTWdhSkNZb0ZFd3c',
#   'date': '12/01/2023, 08:00 AM, +0000 UTC'},
#  {'position': 83,
#   'title': 'EV용 이차 전지, 제조 공정을 최적화하려면?',
#   'source': {'name': 'GTT KOREA',
#    'icon': 'https://lh3.googleusercontent.com/W1eC1FiEfluXkAsT8rAgnGkF1YsEUo1lrxby6lsu8RWrPl3f--hV3uDZrcP4Bi2mXCcZOvXXuc0'},
#   'link': 'https://www.gttkorea.com/news/articleView.html?idxno=9285',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXFWak15VEV4VE1pMXpjekJFVFJEaEFSamdBU2dCTWdZZE5JYk5tUU0',
#   'date': '03/07/2024, 02:32 AM, +0000 UTC'},
#  {'position': 84,
#   'title': "국가전략산업 '이차전지' 국내 생태계 구축 현황은?",
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=81623',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNHRUMW95V0VSbk56TlVOWEYyVFJDM0FSaVRBaWdCTWdrWlFKUUtKaWdtaUFJ',
#   'date': '09/01/2023, 07:00 AM, +0000 UTC'},
#  {'position': 85,
#   'title': '전북자치도, 글로벌 이차전지 핵심 소재 공급기지 적합지 홍보나서',
#   'source': {'name': '전북도민일보',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.domin.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.domin.co.kr/news/articleView.html?idxno=1460499&sc_section_code=S1N6',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTVOV2ROYWxGM1ltTkhRelppVFJDdUFSaWlBaWdCTWdZSlVhREhwQWs',
#   'date': '03/05/2024, 08:21 AM, +0000 UTC'},
#  {'position': 86,
#   'title': '대전시, 이차전지산업 기업육성 본격 시동걸었다 - 서울경제',
#   'source': {'name': '서울경제신문',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.sedaily.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.sedaily.com/NewsView/2D49SRD505',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNVdkVVEwYWswMWVGaG5iMTlHVFJDb0FSaXNBaWdCTWdzTkVJU011R0pyU3NyRk5B',
#   'date': '01/29/2024, 08:00 AM, +0000 UTC'},
#  {'position': 87,
#   'title': "인하대, '제1회 지·산·학 이차전지' 성과 포럼 개최",
#   'source': {'name': '데일리안',
#    'icon': 'https://lh3.googleusercontent.com/KkFN3VyHtm6KgI2LlE3rElBOUMusvx2E4z5jL--1rzzYxKXBu2Wg4ctsR9YaTMSwbcBq5cVeRdY'},
#   'link': 'https://www.dailian.co.kr/news/view/1337562',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTBRMTlMVjJwcVVWRkdkMGd0VFJDM0FSaVRBaWdCTWdhQklJcXpwQWM',
#   'date': '03/11/2024, 01:12 AM, +0000 UTC'},
#  {'position': 88,
#   'title': '추경호 “이차전지 산업에 5년간 38조원 이상 정책금융 지원”',
#   'source': {'name': '경향신문',
#    'icon': 'https://lh3.googleusercontent.com/CnX-U1tNC08-GHRyKtSMx_-B5Ib28tug0gbIIAog-HY-PrWCUl6juB-M-Ivqu_k47LkL59l-2w'},
#   'link': 'https://m.khan.co.kr/article/202312131434001',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXZXa0UxYlVrMVlYUlBTMnB6VFJDX0FSaUlBaWdCTWdZZFVwZ3FwZ2c',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 89,
#   'title': '이차전지에 38조 정책금융…배터리 재사용 생태계 육성',
#   'source': {'name': 'KBS뉴스',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://news.kbs.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#    'authors': ['박예원']},
#   'link': 'https://news.kbs.co.kr/news/view.do?ncd=7840468',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNW9Ra05rVUcxbk9HdHhXR2wwVFJDb0FSaXNBaWdCTWdhdFpJaVBMUVk',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 90,
#   'title': '5년간 이차전지에 38조 정책금융...새만금에 핵심광물 비축기지 구축',
#   'source': {'name': '조선일보',
#    'icon': 'https://lh3.googleusercontent.com/-WgtipKQnV-mzLSqkX270DgDMzZAQllcNEDecRCHvscuvope6vjTCGl6kEuOfYZnIfPWLNxj5w'},
#   'link': 'https://www.chosun.com/economy/economy_general/2023/12/13/6LLZZDHEIBEIRLS2U45KUZXHEM/',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iMkNnNUZTVUpOUmtKUmVVTjNaRU52VFJDakFSaTJBaWdCTWdzQlFKU1BHU3JnQ3NwQmtn',
#   'date': '12/13/2023, 08:00 AM, +0000 UTC'},
#  {'position': 91,
#   'title': '경북도, 차별화된 이차전지 투자환경 알린다',
#   'source': {'name': '대구신문',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.idaegu.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.idaegu.co.kr/news/articleView.html?idxno=452527',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXRVeTFNWm5aSmN6RTFOREkwVFJDNEFSaVJBaWdCTWdZQmNJanZ5QU0',
#   'date': '03/06/2024, 12:30 PM, +0000 UTC'},
#  {'position': 92,
#   'title': '이차전지 2개 기업, 새만금에 1조 1000억 투자 결정',
#   'source': {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식',
#    'icon': 'https://lh3.googleusercontent.com/89VH4Ns6Wa_GWVoSk1ZJGeI5RhFOvJU7OuPV5-xOfpGlaPuEJNs5dsJmi0QJNnAz-Lm-TRtXxAU'},
#   'link': 'https://www.hellot.net/mobile/article.html?no=85337',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNUVabFF6TWtOT1dYWlFjR3RxVFJDekFSaVpBaWdCTWdNQmNRdw',
#   'date': '12/28/2023, 08:00 AM, +0000 UTC'},
#  {'position': 93,
#   'title': "전북 산학연관, 이차전지 산업 생태계 조성 '본격화'",
#   'source': {'name': '전북일보',
#    'icon': 'https://lh3.googleusercontent.com/3b4nzoOUmmJS8hFJUfJQCgYVTpOcUsUshjmZpWjCXna4oqkJBxizj6OpcPgN2uH6b1KhDYB5xA'},
#   'link': 'https://www.jjan.kr/article/20230925580306',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNHplRUprUmw4elNUSkVObTA0VFJDS0FSanNBaWdCTWdNQlVRdw',
#   'date': '09/25/2023, 07:00 AM, +0000 UTC'},
#  {'position': 94,
#   'title': "추경호 '연내 2차전지 산업 경쟁력 강화 방안 발표' - 서울경제",
#   'source': {'name': '서울경제신문',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.sedaily.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.sedaily.com/NewsView/29VTEVTDOH',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXdOMUo1YjFWZlRqUnVOVFZ3VFJDNkFSaVBBaWdCTWdhaFVveHduUWs',
#   'date': '10/03/2023, 07:00 AM, +0000 UTC'},
#  {'position': 95,
#   'title': '대전시, 이차전지산업 유망기업 육성 < 보도자료 < 충청권 < 전국네트워크 < 기사본문',
#   'source': {'name': '환경일보',
#    'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.hkbs.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://www.hkbs.co.kr/news/articleView.html?idxno=742499',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNTJiUzF6YmtWamJsOWpZWEJGVFJDX0FSaUlBaWdCTWdhSkVvU3RuUWM',
#   'date': '01/29/2024, 08:00 AM, +0000 UTC'},
#  {'position': 96,
#   'title': '[이차전지특구_충북청주] 충북도, 이차전지 산업 글로벌 허브 구축 나선다',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=50422',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNXlibTFrZFhjME5qVTBNMkprVFJDM0FSaVRBaWdCTWdtZE1vRDBwS2lTcGdJ',
#   'date': '07/20/2023, 07:00 AM, +0000 UTC'},
#  {'position': 97,
#   'title': '트렌드 - KOTRA 해외시장뉴스 상품·산업 > 트렌드',
#   'source': {'name': 'KOTRA 무역투자24',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://dream.kotra.or.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://dream.kotra.or.kr/user/extra/kotranews/bbs/linkView/jsp/Page.do?dataIdx=203463',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUxSSE5ETkUxck9IazVhM0JRVFJDZkFSaTlBaWdCTWdZWkJKQnFPZ2M',
#   'date': '08/30/2023, 07:00 AM, +0000 UTC'},
#  {'position': 98,
#   'title': '에코프로, 올해 포항에 1조2000억원 투자…“이차 전지 생태계 조성 고도화”',
#   'source': {'name': '헤럴드경제',
#    'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://biz.heraldcorp.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#    'authors': ['김지윤']},
#   'link': 'https://biz.heraldcorp.com/view.php?ud=20240310050033',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iKkNnNWtRV296U25OWFEyNVRabUZwVFJCZUdKa0VLQUV5QnBFRGpLdU5Ddw',
#   'date': '03/10/2024, 12:14 AM, +0000 UTC'},
#  {'position': 99,
#   'title': '에코프로, 올해 국내 1조2000억원 투자 집행…이차전지 복합 투자',
#   'source': {'name': '더팩트',
#    'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://news.tf.co.kr&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#   'link': 'https://news.tf.co.kr/read/economy/2081722.htm',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNDRibWgwVTA1TE9GODRSM3BVVFJDb0FSaXNBaWdCTWdZQmdJUXFOUVU',
#   'date': '03/10/2024, 06:04 AM, +0000 UTC'},
#  {'position': 100,
#   'title': '[이차전지특구-포항①] 경북포항, 철강에서 이차전지로 성공적 산업 재편… 글로벌 이차전지 허브 꿈꾼다',
#   'source': {'name': '인더스트리뉴스',
#    'icon': 'https://lh3.googleusercontent.com/Yc3IkWXSHdQ3OgWAPtcpuEiwwr2EmsCZ0ojnB0EqAUDgL8kj2Y7kiWerT8AM59gEEiPMsSeC3A'},
#   'link': 'https://www.industrynews.co.kr/news/articleView.html?idxno=52328',
#   'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNHRWVXBrWlRWc2RHWkZjRUZJVFJDM0FSaVRBaWdCTWdZQmNJQkx5UU0',
#   'date': '02/06/2024, 08:00 AM, +0000 UTC'}]

# %%
results = search.run("이차전지 산업")
len(results)
# Out:
# 100

# %%
results[0]
# Out:
# {'position': 1,
#  'title': '이차전지 산업 성과와 향후 과제는',
#  'source': {'name': '전자신문',
#   'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#  'link': 'https://www.etnews.com/20240311000263',
#  'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNUtaRTVuVm5NeE5rMWFWelJoVFJDZUFSaV9BaWdCTWdtTlVJUkdUcU10S1FJ',
#  'date': '03/11/2024, 05:26 AM, +0000 UTC'}

# %%
results[0].keys()
# Out:
# dict_keys(['position', 'title', 'source', 'link', 'thumbnail', 'date'])

# %%
url = results[0]['link']
url
# Out:
# 'https://www.etnews.com/20240311000263'

# %% [markdown]
# ### LangChain WebBaseLoader 활용

# %%
# Data Loader - 웹페이지 데이터 가져오기
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(url)
docs = loader.load()

docs[0]
# Out:
# Document(page_content="\n\n\n\n\n\n\n이차전지 산업 성과와 향후 과제는 - 전자신문\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nConference\nallshowTV\nEnglish\nETstudio\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n뉴스\n속보\n경제·금융\n전자·모빌리티\n통신·미디어·게임\n소재·부품\nAI·SW·보안\n산업·에너지·환경\n플랫폼·유통\n헬스케어·벤처\n\n\n뉴스\n정치\n전국\n국제\n골프\n화제의뉴스\n인사·부음\n오피니언\n특집\n연재\n\n\n비주얼IT\n스페셜리포트\nETstudio\n뷰포인트\n인포그래픽\n\n\n라이프\n연예\n포토\n공연전시\n생활문화\n\n\n\n\n부가서비스\nIT교육지원캠페인\n콘퍼런스\nallshowTV\nIT 전시 컨벤션\nET프리미엄\n시사용어\nPDF 서비스\nEnglish\n\n\n서비스 안내\n신문구독신청\n온라인광고안내\n콘텐츠구매\n초판서비스\n번역센터\n\n\n회원 서비스\n로그인\n회원가입\n\n\n\n\n패밀리미디어\nRPM9\n\n\n\n\n\n\n\n\n\n\n경제·금융\n\n\n\n전자·모빌리티\n\n\n\n통신·미디어·게임\n\n\n\n소재·부품\n\n\n\nAI·SW·보안\n\n\n\n산업·에너지·환경\n\n\n\n플랫폼·유통\n\n\n\n헬스케어·벤처\n\n\n\n정치\n\n\n\n전국\n\n\n\n국제\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n이차전지 산업 성과와 향후 과제는\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n발행일 : 2024-03-11 14:26\n\n\n\n\n\n\n\n\n민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국기술센터에서 열렸다. 안덕근 산업통상자원부 장관이 모두발언을 하고 있다.\n이동근기자 foto@etnews.com\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\nEU CBAM 및 배터리 규제 대응 솔루션 실제 구축 사례\n\n\n\nFPT의 Cockpit Domain Controller(CDC)로소프트웨어 정의 차량 시대로의 전환 가속화\n\n\n\n\n\nBRAND NEWSROOM\n\n\n\n슈퍼솔루션슈퍼마이크로, 5G·클라우드 워크로드 가속화 솔루션 구축\n여의시스템여의시스템, '인터배터리 2024' 참가…UL(cUL)인증 산업용컴퓨터, Moxa 솔루션공개\n로옴세미컨덕터코리아로옴, SOT23 패키지 채용한 소형·저전력 'DC-DC 컨버터 IC' 개발\n\n\n마이스터즈마이스터즈, 기술보증기금 프리A 유치…성장잠재력 입증\n한국메타버스산업협회한국메타버스산업협회, “가상융합산업 진흥법안 통과 환영”\n시큐어링크시큐어링크, 2023 글로벌 AI 보안 컨퍼런스 'AI+SECURITY 데모데이' 대상 수상\n\n\n위엠비위엠비-엑솔, IT 솔루션 공급 및 공동 마케팅 사업 제휴\n인아그룹인아그룹, '세미콘 코리아 2024' 성료\n큐알티큐알티-KIST, 우주용 반도체 평가 기술 공동연구\n\n\n한국무라타전자무라타, IEEE Milestone상 수상…MLCC 상용화 공헌\n유니온커뮤니티유니온커뮤니티 “ISO 2종 인증 획득, GDPR 준수 앞장선다”\n한국태양유전태양유전, R&D센터에 태양광발전 가동 개시\n\n\n토마토시스템토마토시스템, 美 '챔피언 헬스플랜'과 서비스 계약\n\n\n\n\n\n\n\n\n\n\n\n많이 본 뉴스\n\n\n\n1\n\n이미지센서 1위 소니, 한국서 후공정 추진…삼성 타깃, 韓 협력사 선정 착수\n\n\n\n\n\n\n2\n\n'칩 256개를 동시에' 에이엠티, HBM 검사장비 개발\n\n\n\n\n\n\n3\n\nVM웨어 가격 인상, 대기업까지 덮쳤다\n\n\n\n\n\n\n4\n\n에코프로, '전구체 프리' LFP 양극재 만든다\n\n\n\n\n\n\n5\n\n'유리기판·2.5D 확보'…550억 규모 차세대 반도체 패키징 R&D 시동\n\n\n\n\n\n\n\nBIZPLUS\n\n\nEU CBAM 및 배터리 규제 대응 솔루션 실제 구축 사례\n\n\n[올쇼TV]FPT의 소프트웨어 정의 차량 시대로의 전환 가속화, 3월 14일 생방송\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n전자신문\n회사소개\n지면광고\n행사문의\n\n\n\n주소: 서울시 서초구 양재대로2길 22-16 호반파크1관 8~9층 대표번호: 02-2168-9200 구독문의:  02-2671-1806~7\n            \n\n\n전자신문인터넷\n회사소개\n이용약관\n개인정보취급방침\n고충처리\n사이트맵\n\n\n\n주소: 서울시 서초구 양재대로2길 22-16 호반파크1관 7층 대표번호: 02-857-0114\n              사업자번호: 107-81-80959 등록번호: 서울 아04494 \n제호: 전자신문인터넷 등록일자: 2017년 04월 27일 발행일자: 1996년 04월 10일 발행·편집인: 심규호\n              청소년보호책임자: 김인기\n            \nCopyright © Electronic Times Internet. All Rights Reserved. \n\n\n\n\n\n패밀리미디어\nRPM9\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n", metadata={'source': 'https://www.etnews.com/20240311000263', 'title': '이차전지 산업 성과와 향후 과제는 - 전자신문', 'description': '미래를 보는 신문 - 전자신문', 'language': 'ko'})

# %%
# 뉴스기사에서 본문 텍스트를 추출하는 함수
def extract_longest_text(text):
    # 개행문자(\n\n)를 기준으로 텍스트를 분할
    segments = text.split('\n')
    # 가장 긴 텍스트 조각을 찾음
    longest_segment = max(segments, key=len)
    return longest_segment

text = docs[0].page_content

longest_text = extract_longest_text(text)
print("가장 긴 텍스트:\n", longest_text)
# Out:
# 가장 긴 텍스트:
#  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국기술센터에서 열렸다. 안덕근 산업통상자원부 장관이 모두발언을 하고 있다.

# %%
# SerpAPI 검색 결과를 순회하면서 본문 텍스트를 추출하여 기존 딕셔너리에 추가

from tqdm import tqdm
import time

new_results = []
for result in tqdm(results):
    try:
        url = result['link']
        loader = WebBaseLoader(url)
        docs = loader.load()
        text = docs[0].page_content
        longest_text = extract_longest_text(text)
        result['content'] = longest_text
        new_results.append(result)
    except:
        pass


# 결과 확인
print("새로운 결과 개수:", len(new_results))
new_results[0]
# Out:
# 100%|██████████| 100/100 [00:35<00:00,  2.85it/s]
# 새로운 결과 개수: 98
# {'position': 1,
#  'title': '이차전지 산업 성과와 향후 과제는',
#  'source': {'name': '전자신문',
#   'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.etnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'},
#  'link': 'https://www.etnews.com/20240311000263',
#  'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNUtaRTVuVm5NeE5rMWFWelJoVFJDZUFSaV9BaWdCTWdtTlVJUkdUcU10S1FJ',
#  'date': '03/11/2024, 05:26 AM, +0000 UTC',
#  'content': '민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국기술센터에서 열렸다. 안덕근 산업통상자원부 장관이 모두발언을 하고 있다.'}

# %% [markdown]
# # 판다스 데이터프레임으로 변환

# %%
import pandas as pd
data = pd.DataFrame(new_results)
data.head()
# Out:
#    position                                              title  \
# 0         1                                 이차전지 산업 성과와 향후 과제는
# 1         2  윤신애 군산시의원, '군산새만금 이차전지산업 발전위원회 설치 및 운영조례안' 상임위...
# 2         3  [이차전지특구-충북②] 충북도 김명규 경제부지사, “국내 1위 넘어 글로벌 배터리 ...
# 3         4             [프리뷰 2024 ②] 주춤하는 전기차 시장, 올해 이차전지 산업은?
# 4         5              경북도, 이차전지 산업생태계와 산업단지 홍보 등 기업유치 활동 실시
#
#                                               source  \
# 0  {'name': '전자신문', 'icon': 'https://encrypted-tb...
# 1  {'name': '아시아뉴스전북', 'icon': 'https://lh3.googl...
# 2  {'name': '인더스트리뉴스', 'icon': 'https://lh3.googl...
# 3  {'name': '헬로티 – 매일 만나는 첨단 산업, IT 소식', 'icon': ...
# 4  {'name': 'Save Internet 뉴데일리', 'icon': 'https:...
#
#                                                 link  \
# 0              https://www.etnews.com/20240311000263
# 1  http://www.mjeonbuk.com/news/articleView.html?...
# 2  https://www.industrynews.co.kr/news/articleVie...
# 3  https://www.hellot.net/mobile/article.html?no=...
# 4  https://tk.newdaily.co.kr/site/data/html/2024/...
#
#                                            thumbnail  \
# 0  https://news.google.com/api/attachments/CC8iL0...
# 1  https://news.google.com/api/attachments/CC8iK0...
# 2  https://news.google.com/api/attachments/CC8iK0...
# 3  https://news.google.com/api/attachments/CC8iK0...
# 4  https://news.google.com/api/attachments/CC8iK0...
#
#                               date  \
# 0  03/11/2024, 05:26 AM, +0000 UTC
# 1  03/12/2024, 06:56 AM, +0000 UTC
# 2  03/07/2024, 01:00 AM, +0000 UTC
# 3  01/03/2024, 08:00 AM, +0000 UTC
# 4  03/06/2024, 02:19 PM, +0000 UTC
#
#                                              content
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
# 3  서 상무에 따르면 2023년 약 969GWh의 이차전지 수요가 오는 2030년에는 ...
# 4  경상북도는 6일부터 8일까지 서울 코엑스에서 열리는 ‘인터배터리 2024 전시회’에...

# %% [markdown]
# # 뉴스 요약

# %%
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# prompt
prompt_template = """Write a concise summary of the following in Korean Hangul (한글):
"{text}"
CONCISE SUMMARY:"""
prompt = PromptTemplate.from_template(prompt_template)

# LLM
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125")

# output parser
output_parser = StrOutputParser()

# Chain
llm_chain = prompt | llm | output_parser

response = llm_chain.invoke({"text": data['content'][0]})

response
# Out:
# '한국기술센터에서 열린 제3차 수출·현안 전략회의에 안덕근 장관이 발언하고 있다.'

# %%
# 뉴스 본문을 입력으로 사용하여 요약 결과를 생성하는 함수
def summarize_news(content):
    response = llm_chain.invoke({"text": content})
    return response

# 결과 확인 - 테스트를 위해서 첫 3행만 별도로 추출하여 요약
df_test = data.head(3)
df_test['summary'] = df_test['content'].apply(summarize_news)

df_test
# Out:
# /var/folders/nd/kfl3k2197fv3vr63kpjrnrg00000gn/T/ipykernel_5239/3536674286.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['summary'] = df_test['content'].apply(summarize_news)
#    position                                              title  \
# 0         1                                 이차전지 산업 성과와 향후 과제는
# 1         2  윤신애 군산시의원, '군산새만금 이차전지산업 발전위원회 설치 및 운영조례안' 상임위...
# 2         3  [이차전지특구-충북②] 충북도 김명규 경제부지사, “국내 1위 넘어 글로벌 배터리 ...
#
#                                               source  \
# 0  {'name': '전자신문', 'icon': 'https://encrypted-tb...
# 1  {'name': '아시아뉴스전북', 'icon': 'https://lh3.googl...
# 2  {'name': '인더스트리뉴스', 'icon': 'https://lh3.googl...
#
#                                                 link  \
# 0              https://www.etnews.com/20240311000263
# 1  http://www.mjeonbuk.com/news/articleView.html?...
# 2  https://www.industrynews.co.kr/news/articleVie...
#
#                                            thumbnail  \
# 0  https://news.google.com/api/attachments/CC8iL0...
# 1  https://news.google.com/api/attachments/CC8iK0...
# 2  https://news.google.com/api/attachments/CC8iK0...
#
#                               date  \
# 0  03/11/2024, 05:26 AM, +0000 UTC
# 1  03/12/2024, 06:56 AM, +0000 UTC
# 2  03/07/2024, 01:00 AM, +0000 UTC
#
#                                              content  \
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
#
#                                              summary
# 0  한국에서 민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 열렸고, 안덕근...
# 1  윤신애 의원은 작년 발의한 군산 새만금신항 발전위원회 설치 및 운영조례로 새만금 개...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...

# %%
df_test[['content', 'summary']]
# Out:
#                                              content  \
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
#
#                                              summary
# 0  한국에서 민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 열렸고, 안덕근...
# 1  윤신애 의원은 작년 발의한 군산 새만금신항 발전위원회 설치 및 운영조례로 새만금 개...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...

# %% [markdown]
# # 키워드 추출

# %%
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# prompt
prompt_template = """Please extract 3 key words from the following content in Korean Hangul (한글) and separate them with commas (,):
"{text}"
Key words:"""

prompt = PromptTemplate.from_template(prompt_template)

# LLM
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125")

# output parser
output_parser = StrOutputParser()

# Chain
llm_chain = prompt | llm | output_parser

response = llm_chain.invoke({"text": data['content'][0]})

response
# Out:
# '합동, 배터리, 현안'

# %%
# 뉴스 본문을 입력으로 사용하여 핵심 키워드를 추출하는 함수
def extract_keywords(content):
    response = llm_chain.invoke({"text": content})
    return response

# 결과 확인 - 테스트를 위해서 첫 3행만 별도로 추출하여 추출
df_test['keywords'] = df_test['content'].apply(extract_keywords)

df_test[['content', 'summary', 'keywords']]
# Out:
# /var/folders/nd/kfl3k2197fv3vr63kpjrnrg00000gn/T/ipykernel_5239/77447675.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['keywords'] = df_test['content'].apply(extract_keywords)
#                                              content  \
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
#
#                                              summary         keywords
# 0  한국에서 민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 열렸고, 안덕근...      배터리, 수출, 현안
# 1  윤신애 의원은 작년 발의한 군산 새만금신항 발전위원회 설치 및 운영조례로 새만금 개...  윤신애, 새만금, 발전위원회
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...     이차전지, 국내, 충북

# %% [markdown]
# # 뉴스 카테고리 분류

# %%
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# prompt
prompt_template = """Based on the following content, please classify the news into the appropriate category and provide the category name in Korean Hangul (한글):
"{text}"
News Category:"""

prompt = PromptTemplate.from_template(prompt_template)

# LLM
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125")

# output parser
output_parser = StrOutputParser()

# Chain
llm_chain = prompt | llm | output_parser

response = llm_chain.invoke({"text": data['content'][0]})

response
# Out:
# '경제 (Economy) - 경제'

# %%
# 뉴스 본문을 입력으로 사용하여 카테고리를 분류하는 함수
def classify_news_category(content):
    response = llm_chain.invoke({"text": content})
    return response

# 결과 확인 - 테스트를 위해서 첫 3행만 별도로 추출하여 카테고리 분류
df_test['category'] = df_test['content'].apply(classify_news_category)

df_test[['content', 'summary', 'keywords', 'category']]
# Out:
# /var/folders/nd/kfl3k2197fv3vr63kpjrnrg00000gn/T/ipykernel_5239/2226806532.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['category'] = df_test['content'].apply(classify_news_category)
#                                              content  \
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
#
#                                              summary         keywords  \
# 0  한국에서 민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 열렸고, 안덕근...      배터리, 수출, 현안
# 1  윤신애 의원은 작년 발의한 군산 새만금신항 발전위원회 설치 및 운영조례로 새만금 개...  윤신애, 새만금, 발전위원회
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...     이차전지, 국내, 충북
#
#         category
# 0  경제 (Gyeongje)
# 1             정치
# 2  산업 (Industry)

# %% [markdown]
# ### 키워드에서 한글만 추출

# %%
import re
korean_word = re.findall(r'[가-힣]+', df_test['category'][0])[0]
korean_word
# Out:
# '경제'

# %%
# 람다 함수를 사용하여 카테고리에서 한글 단어만 추출 
df_test['category'].apply(lambda x: re.findall(r'[가-힣]+', x)[0])
# Out:
# 0    경제
# 1    정치
# 2    산업
# Name: category, dtype: object

# %%
df_test['category'] = df_test['category'].apply(lambda x: re.findall(r'[가-힣]+', x)[0])
df_test[['content', 'summary', 'keywords', 'category']]
# Out:
# /var/folders/nd/kfl3k2197fv3vr63kpjrnrg00000gn/T/ipykernel_5239/1981466824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['category'] = df_test['category'].apply(lambda x: re.findall(r'[가-힣]+', x)[0])
#                                              content  \
# 0  민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 11일 서울 강남구 한국...
# 1  윤신애 의원은 “작년「군산새만금신항 발전위원회 설치 및 운영조례」를 발의, 발전위원...
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...
#
#                                              summary         keywords category
# 0  한국에서 민·관 합동 배터리 얼라이언스 제3차 수출·현안 전략회의가 열렸고, 안덕근...      배터리, 수출, 현안       경제
# 1  윤신애 의원은 작년 발의한 군산 새만금신항 발전위원회 설치 및 운영조례로 새만금 개...  윤신애, 새만금, 발전위원회       정치
# 2  인더스트리뉴스는 2024년 배터리리포트 기획으로 ‘국가첨단전략산업 이차전지 특화단지...     이차전지, 국내, 충북       산업
